# %% [markdown]
# # HW1

# %%
nN = []
nM = []
with open('/home/nancyho/2022summer-git-python_basics/HW1/HW1.txt', 'r') as f:
    for z in f:
        nN.append(len(z)-1)  
with open('/home/nancyho/2022summer-git-python_basics/HW1/HW1.txt', 'r') as f:  
    for z in f:
        if ('!' in z) or ('+' in z) or ('?' in z) or ('-' in z):
            nM.append(len(z)-1)

nA = []
nB = []
nC = []
nD = []
nE = []
nF = []
with open('/home/nancyho/2022summer-git-python_basics/HW1/HW1.txt', 'r') as f:
    for z in f:
        if(len(z) <= 40):
            A = (len(z)-1)
            nA.append(A)
        elif(len(z) > 40 and len(z) <= 50):
            B = (len(z)-1)
            nB.append(B)
        elif(len(z) > 50 and len(z) <= 60):
            C = (len(z)-1)
            nC.append(C)
        elif(len(z) > 60 and len(z) <= 70):
            D = (len(z)-1)
            nD.append(D)
        elif(len(z) > 70 and len(z) <= 80):
            E = (len(z)-1)
            nE.append(E)
        else:
            F = (len(z)-1)
            nF.append(F)

mA = []
mB = []
mC = []
mD = []
mE = []
mF = []
with open('/home/nancyho/2022summer-git-python_basics/HW1/HW1.txt', 'r') as f:
    for z in f:
        while ('!' in z) or ('+' in z) or ('?' in z) or ('-' in z):
            if '!' in z:
                z = z.replace('!','')
            elif '+' in z:
                z = z.replace('+','')
            elif '?' in z:
                z = z.replace('?','')
            elif '-' in z:
                z = z.replace('-','')
            else:
                z = z
               
        if(len(z) <= 40):
            A = (len(z)-1)
            mA.append(A)
        elif(len(z) > 40 and len(z) <= 50):
            B = (len(z)-1)
            mB.append(B)
        elif(len(z) > 50 and len(z) <= 60):
            C = (len(z)-1)
            mC.append(C)
        elif(len(z) > 60 and len(z) <= 70):
            D = (len(z)-1)
            mD.append(D)
        elif(len(z) > 70 and len(z) <= 80):
            E = (len(z)-1)
            mE.append(E)
        else:
            F = (len(z)-1)
            mF.append(F)

L = [
    '%6s'%'length', '%12s'%'before trim', '%11s'%'after trim'+'\n'
    '%6s'%'<=40', '%12d'%len(nA), '%11d'%len(mA)+'\n'
    '%6s'%'<=50', '%12d'%len(nB), '%11d'%len(mB)+'\n'
    '%6s'%'<=60', '%12d'%len(nC), '%11d'%len(mC)+'\n'
    '%6s'%'<=70', '%12d'%len(nD), '%11d'%len(mD)+'\n'
    '%6s'%'<=80', '%12d'%len(nE), '%11d'%len(mE)+'\n'
    '%6s'%'>80', '%12d'%len(nF), '%11d'%len(mF)           
    ]
with open('/home/nancyho/2022summer-git-python_basics/HW1_何蕙如/HW1_何蕙如.txt', 'w') as f:
    print('There are', len(nN), 'sentences in HW1.txt.', len(nM), 'of them include !?+-.', file = f)
    f.writelines(L)
