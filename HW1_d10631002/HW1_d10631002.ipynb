# %%
import pathlib 
print (pathlib.Path)
print(pathlib.Path('55555.txt').parent.absolute())

# %%
with open ('/Users/danny/2022summer-git-python_basics/HW1/HW1.txt') as f:
    c = 0
    for i in f:
        c += 1
    print (c)
# Out:
# 539

# %%
with open ('/Users/danny/2022summer-git-python_basics/HW1/HW1.txt') as f:
    c = 0
    d = 0

    for i in f:
        
        if len(i)<40:
            d += 1
    print (d)
# Out:
# 23

# %%
with open ('/Users/danny/2022summer-git-python_basics/HW1/HW1.txt') as f:
    c = 0
    d = 0
    e = 0
    l = 0
    g = 0
    h = 0
    k = 0
    for i in f:
        
        if len(i)<40:
            d += 1
        elif len(i)>=40 and len(i)< 50:
            e += 1
        elif len(i)>=50 and len(i)< 60:
            l += 1
        elif len(i)>=60 and len(i)< 70:
            g += 1
        elif len(i)>=70 and len(i)< 80:
            h += 1
        else:
            k += 1



    print (c)
    print (d)
    print (e)
    print (l)
    print (g)
    print (h)
    print (k)
# Out:
# 0
# 23
# 147
# 157
# 129
# 67
# 16

# %%
with open ('/Users/danny/2022summer-git-python_basics/HW1/HW1.txt') as f:
    c = 0
    d = []
    for i in f:
        for j in i:
            if j != '!' and j != '?' and j != '+' and j != '-':
                d.append(j)
            print(d, sep='')
# Out:
# L
# o
# r
# e
# m
#
# i
# p
# s
# u
# m
#
# d
# o
# l
# o
# r
#
# s
# i
# t
#
# a
# m
# e
# t
# ,
#
# c
# o
# n
# s
# e
# c
# t
# e
# t
# u
# r
#
# a
# d
# i
# p
# i
# s
# c
# i
# n
# g
#
# e
# l
# i
# t
# .
#
#
# P
# r
# o
# i
# n
#
# l
# u
# c
# t
# u
# s
#
# e
# l
# i
# t
#
# v
# i
# t
# a
# e
#
# m
# e
# t
# u
# s
#
# e
# u
# i
# s
# m
# o
# d
# ,
#
# l
# o
# b
# o
# r
# t
# i
# s
#
# m
# a
# x
# i
# m
# u
# s
#
# a
# r
# c
# u
#
# s
# o
# l
# l
# i
# c
# i
# t
# u
# d
# i
# n
# .
#
#
# V
# e
# s
# t
# i
# b
# u
# l
# u
# m
#
# v
# e
# l
#
# d
# u
# i
#
# i
# n
#
# n
# u
# n
# c
#
# l
# o
# b
# o
# r
# t
# i
# s
#
# l
# a
# c
# i
# n
# i
# a
# .
#
#
# N
# u
# n
# c
#
# i
# n
#
# a
# r
# c
# u
#
# a
# c
#
# m
# i
#
# f
# e
# u
# g
# i
# a
# t
#
# a
# l
# i
# q
# u
# a
# m
# .
#
#
# V
# i
# v
# a
# m
# u
# s
#
# n
# o
# n
#
# m
# e
# t
# u
# s
#
# v
# e
# h
# i
# c
# u
# l
# a
# ,
#
# r
# u
# t
# r
# u
# m
#
# n
# u
# l
# l
# a
#
# a
# t
# ,
#
# a
# l
# i
# q
# u
# e
# t
#
# e
# s
# ...
